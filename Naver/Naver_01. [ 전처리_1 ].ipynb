# %% [markdown]
# # 전처리 1

# %%
import pandas as pd
import numpy as np
import re
import copy
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline
from kiwipiepy import Kiwi
from kiwipiepy.utils import Stopwords
pd.options.mode.chained_assignment = None  # 경고 숨기기

# %%
# 데이터 불러오기
news = pd.read_csv('naver_drop_duplicates.csv')
news
# Out:
#                                                   Title        Date
# 0                       네이버, 금지·혐오 표현 기준 개정…12일부터 정책 적용  2023.06.01
# 1                  네이버, 초거대 AI로 소상공인 라이브커머스 대본 작성 돕는 이유  2023.06.01
# 2                               네이버 악성 댓글땐 ‘악플러 꼬리표’ 단다  2023.06.01
# 3                             네이버가 4달간 중소상공인 브랜드 구축 돕는다  2023.06.01
# 4                      네이버·카카오 인물정보에 '장례지도사' 등 5개 직업 추가  2023.06.01
# ...                                                 ...         ...
# 9340                티몬, 브랜드 단위 협업으로 직구 강화…"큐텐 시너지로 차별화"  2024.05.27
# 9341      카카오·라인야후, 어떻게 해커에 뚫렸나… “오픈채팅방 ID 구조 단순”vs“...  2024.05.27
# 9342      네이버웹툰 ‘꿈에서 자유로’ 오는 6월 두 번째 오디오 웹툰 텀블럭 펀딩 실...  2024.05.27
# 9343                 “삼성 출신 들어가니 좀 달라졌네”…요즘 국회는 ‘AI 열공’  2024.05.27
# 9344  [창간 9주년 韓에 AI(혼)를 심다] 최수연 네이버 대표 "올해 서비스 전반에 생...  2024.05.27
#
# [9345 rows x 2 columns]

# %% [markdown]
# ### 1. Date 컬럼 형식 맞추기 - '실제 주식 데이터'와 비교 위해서

# %%
### 1. Date 컬럼 형식 맞추기 - '실제 주식 데이터'와 비교 위해서
news['Date'] = pd.to_datetime(news['Date'], format='%Y.%m.%d').dt.strftime('%Y-%m-%d')
# 컬럼 순서 변경
news = news[['Date', 'Title']]
news
# Out:
#             Date                                              Title
# 0     2023-06-01                    네이버, 금지·혐오 표현 기준 개정…12일부터 정책 적용
# 1     2023-06-01               네이버, 초거대 AI로 소상공인 라이브커머스 대본 작성 돕는 이유
# 2     2023-06-01                            네이버 악성 댓글땐 ‘악플러 꼬리표’ 단다
# 3     2023-06-01                          네이버가 4달간 중소상공인 브랜드 구축 돕는다
# 4     2023-06-01                   네이버·카카오 인물정보에 '장례지도사' 등 5개 직업 추가
# ...          ...                                                ...
# 9340  2024-05-27                티몬, 브랜드 단위 협업으로 직구 강화…"큐텐 시너지로 차별화"
# 9341  2024-05-27      카카오·라인야후, 어떻게 해커에 뚫렸나… “오픈채팅방 ID 구조 단순”vs“...
# 9342  2024-05-27      네이버웹툰 ‘꿈에서 자유로’ 오는 6월 두 번째 오디오 웹툰 텀블럭 펀딩 실...
# 9343  2024-05-27                 “삼성 출신 들어가니 좀 달라졌네”…요즘 국회는 ‘AI 열공’
# 9344  2024-05-27  [창간 9주년 韓에 AI(혼)를 심다] 최수연 네이버 대표 "올해 서비스 전반에 생...
#
# [9345 rows x 2 columns]

# %% [markdown]
# # 2. 텍스트 정제된 ppc_Title 컬럼 만들기

# %%
### 2. 텍스트 정제
def preprocess_title(text):  
    text = text.upper()  # (1) 대문자로 변환
    text = re.sub(r'\[.*?\]', ' ', text)   # (2) 대괄호 및 그 안의 내용 제거
    text = re.sub(r'[^\w\s]', ' ', text)  # (3) 특수 문자 제거 및 공백 유지
    text = text.strip() # (4) 문자열 앞뒤 공백 제거
    return text
# 'Title' 컬럼에 텍스트 정제 함수 적용
news['ppc_Title'] = news['Title'].apply(preprocess_title)

# %%
news
# Out:
#             Date                                              Title  \
# 0     2023-06-01                    네이버, 금지·혐오 표현 기준 개정…12일부터 정책 적용
# 1     2023-06-01               네이버, 초거대 AI로 소상공인 라이브커머스 대본 작성 돕는 이유
# 2     2023-06-01                            네이버 악성 댓글땐 ‘악플러 꼬리표’ 단다
# 3     2023-06-01                          네이버가 4달간 중소상공인 브랜드 구축 돕는다
# 4     2023-06-01                   네이버·카카오 인물정보에 '장례지도사' 등 5개 직업 추가
# ...          ...                                                ...
# 9340  2024-05-27                티몬, 브랜드 단위 협업으로 직구 강화…"큐텐 시너지로 차별화"
# 9341  2024-05-27      카카오·라인야후, 어떻게 해커에 뚫렸나… “오픈채팅방 ID 구조 단순”vs“...
# 9342  2024-05-27      네이버웹툰 ‘꿈에서 자유로’ 오는 6월 두 번째 오디오 웹툰 텀블럭 펀딩 실...
# 9343  2024-05-27                 “삼성 출신 들어가니 좀 달라졌네”…요즘 국회는 ‘AI 열공’
# 9344  2024-05-27  [창간 9주년 韓에 AI(혼)를 심다] 최수연 네이버 대표 "올해 서비스 전반에 생...
#
#                                        ppc_Title
# 0                네이버  금지 혐오 표현 기준 개정 12일부터 정책 적용
# 1           네이버  초거대 AI로 소상공인 라이브커머스 대본 작성 돕는 이유
# 2                        네이버 악성 댓글땐  악플러 꼬리표  단다
# 3                      네이버가 4달간 중소상공인 브랜드 구축 돕는다
# 4               네이버 카카오 인물정보에  장례지도사  등 5개 직업 추가
# ...                                          ...
# 9340          티몬  브랜드 단위 협업으로 직구 강화  큐텐 시너지로 차별화
# 9341   카카오 라인야후  어떻게 해커에 뚫렸나   오픈채팅방 ID 구조 단순 VS
# 9342  네이버웹툰  꿈에서 자유로  오는 6월 두 번째 오디오 웹툰 텀블럭 펀딩 실
# 9343            삼성 출신 들어가니 좀 달라졌네  요즘 국회는  AI 열공
# 9344                    최수연 네이버 대표  올해 서비스 전반에 생
#
# [9345 rows x 3 columns]

# %% [markdown]
# # 3. ppc_Title 컬럼 중복 확인 및 제거

# %%
# 중복 확인
print(news[news.duplicated(subset='ppc_Title')==True].count())
news[news.duplicated(subset='ppc_Title', keep=False)].head()

# => 중복 원인
# Title을 전처리 하면서 동일한 내용이 됨
# Out:
# Date         24
# Title        24
# ppc_Title    24
# dtype: int64
#             Date                                  Title  \
# 1242  2023-07-17          "해운대 우수상품 '네이버 쇼핑 라이브'에서 만나요"
# 1261  2023-07-18            [Who Is ?] 이해진 네이버 글로벌투자책임자
# 1435  2023-07-24            해운대 우수상품 ‘네이버 쇼핑 라이브’에서 만나요
# 2983  2023-09-19  DGB금융그룹, 네이버 해피빈 '이달의 기부'로 추석맞이 아동 지원
# 2992  2023-09-19  DGB금융그룹, 네이버 해피빈 ‘이달의 기부’로 추석맞이 아동 지원
#
#                                   ppc_Title
# 1242            해운대 우수상품  네이버 쇼핑 라이브 에서 만나요
# 1261                       이해진 네이버 글로벌투자책임자
# 1435            해운대 우수상품  네이버 쇼핑 라이브 에서 만나요
# 2983  DGB금융그룹  네이버 해피빈  이달의 기부 로 추석맞이 아동 지원
# 2992  DGB금융그룹  네이버 해피빈  이달의 기부 로 추석맞이 아동 지원

# %%
### 3. 중복 제거
news = news.drop_duplicates(subset='ppc_Title', keep='first')

# %%
# 중복 제거 확인
print(news[news.duplicated(subset='ppc_Title')==True].count())
news[news.duplicated(subset='ppc_Title')==True]
# Out:
# Date         0
# Title        0
# ppc_Title    0
# dtype: int64
# Empty DataFrame
# Columns: [Date, Title, ppc_Title]
# Index: []

# %% [markdown]
# # 4. 띄어쓰기 기준 명사만 추출하여 Tokens 컬럼 만들기

# %%
### 4. 띄어쓰기 후 각 단어 형태소 분석 -> 명사만 추출
kiwi = Kiwi(typos='basic')
stopwords = Stopwords()

def tokenize_text(text):
    words = text.split()  # (1) 띄어쓰기로 텍스트 나누기
    token_list = []
    for word in words:
        tokens = kiwi.tokenize(word)  # (2) 각 단어를 형태소 분석
        for token in tokens:
            if token.tag in ['NNG', 'NNP']:   # (3) 명사(NNG, NNP)만 추출
                token_list.append(token.form)
    return token_list
news['Tokens'] = news['ppc_Title'].apply(tokenize_text)

# %%
news.head(50)
# Out:
#           Date                                           Title  \
# 0   2023-06-01                 네이버, 금지·혐오 표현 기준 개정…12일부터 정책 적용
# 1   2023-06-01            네이버, 초거대 AI로 소상공인 라이브커머스 대본 작성 돕는 이유
# 2   2023-06-01                         네이버 악성 댓글땐 ‘악플러 꼬리표’ 단다
# 3   2023-06-01                       네이버가 4달간 중소상공인 브랜드 구축 돕는다
# 4   2023-06-01                네이버·카카오 인물정보에 '장례지도사' 등 5개 직업 추가
# 5   2023-06-01                   현대차證 “네이버, 하이퍼클로바X 시장 연착륙할 것”
# 6   2023-06-01          재난상황 ‘주연’된 네이버...공공인프라 된 플랫폼, 책임 어디까지?
# 7   2023-06-01                  AI 웹툰 논란에 네이버·카카오 "인간 작품만 받는다"
# 8   2023-06-01             네이버가 300억 투자한 패션 플랫폼 ‘브랜디’ 자금 수혈 필요
# 9   2023-06-01                네이버 마비, 5분 만에 복구됐지만… 실제 재난에선 어쩌나
# 10  2023-06-01            “트위터 보단 네이버 사용자가 훨씬 많은데…‘실검’ 부활시켰으면”
# 11  2023-06-01              ‘김현철 국정개입 폭로’ 의사, 네이버 고소…“내 자료 파기”
# 12  2023-06-01  ‘소년판타지’, MBC-네이버 나우-아베마(ABEMA), 127분 생방송 동시 중계
# 13  2023-06-01                    前 YS 주치의, 네이버 고소…"내 자료 무단삭제"
# 14  2023-06-01                北 발사체 경보 뒤 네이버 5분간 먹통… 시민들 혼란 가중
# 15  2023-06-01                    네이버 계열사 7곳, 임금인상 4.8~6% 잠정합의
# 16  2023-06-01           與 포털위, 네이버 뉴스 개편에 "언론사 클릭장사 격화 우려 나와"
# 17  2023-06-01    네이버페이 대출 갈아타기 오픈… 낮은 금리로 갈아타고 잘 갚으면 포인트 지...
# 18  2023-06-01             '네이버 검색 순위 조작'은 돈이 된다, 하지만 검찰에 들켰죠?
# 19  2023-06-01            "네이버판 로켓배송인거에요?" 네이버 도착보장에 맘카페도 '꿈틀'
# 20  2023-06-01                           北 발사체에 네이버도 모바일 접속 장애
# 21  2023-06-01               언총, 네이버 겨냥 "뉴스장사 아닌 뉴스 공정성 얘기할 때"
# 22  2023-06-01          트리니티소프트 '코드레이 엑스지 V6.0', 네이버 마켓플레이스 등록
# 23  2023-06-01                [오늘의 증시 리포트] “네이버, AI와 로봇에 건 미래”
# 24  2023-06-01                           北 발사체 경보 뒤 네이버 5분간 먹통
# 25  2023-06-01                네이버 "생성형 AI 도입돼도 검색 광고 수요 여전할 것"
# 26  2023-06-01                  서비스 개편 나선 네이버ㆍ카카오, 새 먹거리 발굴 속도
# 27  2023-06-01                   오퀴즈 '에스트라 네이버 쇼핑 라이브' 8시 정답은?
# 28  2023-06-01             미래에셋증권, 네이버클라우드와 손잡고 ‘빅데이터 페스티벌’ 개최
# 29  2023-06-01                        재난 경보에 먹통된 네이버…"서버 확충해야"
# 30  2023-06-01            '단기차입금' 증가한 네이버클라우드, 하이퍼클로바X로 기회 찾을까
# 31  2023-06-01                       서울디지털재단–네이버클라우드, 업무 협약 체결
# 32  2023-06-01             글로벌 3대 AI학회 논문수, 삼성 17위-네이버 18위 머물러
# 33  2023-06-01     산업부, 하드웨어 첨단전략산업 '총력대응'에 최수연 네이버 대표 포함...왜?
# 34  2023-06-01   경기동부 우수 소상공인 기획전 '장인의 앞뜰리에' 20일간 네이버와 롯데온에...
# 35  2023-06-01  엔씨디지텍, 네이버 스토어 '갤럭시북 HOT SUMMER' 특가 프로모션 행사 진행
# 36  2023-06-01             잇따라 서버 불안정 일으킨 네이버…“트래픽 집중 대비책 세워야”
# 37  2023-06-01       [포털 정상화 속도전] 당정 "네이버·다음 독과점 심각…연내 정상화할 것"
# 38  2023-06-01          [종합주가지수] 밀린 코스피, LG에너지솔루션·네이버 등 엇갈린 주가
# 39  2023-06-01               신세계 유니버스클럽 흥행할까…쿠팡·네이버 멤버십과 비교해보니
# 40  2023-06-02         태평양도서 5개국, 네이버 1784 방문…"IT 기술력이 국가 경쟁력"
# 41  2023-06-02               네이버 인물정보 항목 다양화…본인 참여 서비스 모바일로 확대
# 42  2023-06-02                        통계청-네이버, 초거대 AI 협업 방안 모색
# 43  2023-06-02          네이버·토스 대환대출 플랫폼에 국민·신한은행 빠진 까닭은[경제블로그]
# 44  2023-06-02                               [잇속] SKT·KT·네이버 외
# 45  2023-06-02            "회원관리 손쉽게"…카페24 '네이버 로그인 플러스 위자드' 선봬
# 46  2023-06-02                   네이버, 임직원과 로컬 SME가 직접 만나 소통 강화
# 47  2023-06-02              한상혁 찍어내고 네이버·다음 손보기? '관제 포털' 시대 오나
# 48  2023-06-02                  네이버 '뷰티·해외직구 윈도' 종료…패션타운에 새 둥지
# 49  2023-06-02                      앳홈, 미닉스 미니 건조기 네이버 쇼핑에서 론칭
#
#                                          ppc_Title  \
# 0                  네이버  금지 혐오 표현 기준 개정 12일부터 정책 적용
# 1             네이버  초거대 AI로 소상공인 라이브커머스 대본 작성 돕는 이유
# 2                          네이버 악성 댓글땐  악플러 꼬리표  단다
# 3                        네이버가 4달간 중소상공인 브랜드 구축 돕는다
# 4                 네이버 카카오 인물정보에  장례지도사  등 5개 직업 추가
# 5                     현대차證  네이버  하이퍼클로바X 시장 연착륙할 것
# 6            재난상황  주연 된 네이버   공공인프라 된 플랫폼  책임 어디까지
# 7                    AI 웹툰 논란에 네이버 카카오  인간 작품만 받는다
# 8              네이버가 300억 투자한 패션 플랫폼  브랜디  자금 수혈 필요
# 9                 네이버 마비  5분 만에 복구됐지만  실제 재난에선 어쩌나
# 10              트위터 보단 네이버 사용자가 훨씬 많은데  실검  부활시켰으면
# 11                김현철 국정개입 폭로  의사  네이버 고소  내 자료 파기
# 12   소년판타지   MBC 네이버 나우 아베마 ABEMA   127분 생방송 동시 중계
# 13                     前 YS 주치의  네이버 고소  내 자료 무단삭제
# 14                北 발사체 경보 뒤 네이버 5분간 먹통  시민들 혼란 가중
# 15                    네이버 계열사 7곳  임금인상 4 8 6  잠정합의
# 16            與 포털위  네이버 뉴스 개편에  언론사 클릭장사 격화 우려 나와
# 17       네이버페이 대출 갈아타기 오픈  낮은 금리로 갈아타고 잘 갚으면 포인트 지
# 18               네이버 검색 순위 조작 은 돈이 된다  하지만 검찰에 들켰죠
# 19              네이버판 로켓배송인거에요   네이버 도착보장에 맘카페도  꿈틀
# 20                           北 발사체에 네이버도 모바일 접속 장애
# 21                언총  네이버 겨냥  뉴스장사 아닌 뉴스 공정성 얘기할 때
# 22          트리니티소프트  코드레이 엑스지 V6 0   네이버 마켓플레이스 등록
# 23                               네이버  AI와 로봇에 건 미래
# 24                           北 발사체 경보 뒤 네이버 5분간 먹통
# 25                 네이버  생성형 AI 도입돼도 검색 광고 수요 여전할 것
# 26                  서비스 개편 나선 네이버ㆍ카카오  새 먹거리 발굴 속도
# 27                    오퀴즈  에스트라 네이버 쇼핑 라이브  8시 정답은
# 28             미래에셋증권  네이버클라우드와 손잡고  빅데이터 페스티벌  개최
# 29                         재난 경보에 먹통된 네이버  서버 확충해야
# 30             단기차입금  증가한 네이버클라우드  하이퍼클로바X로 기회 찾을까
# 31                       서울디지털재단 네이버클라우드  업무 협약 체결
# 32             글로벌 3대 AI학회 논문수  삼성 17위 네이버 18위 머물러
# 33      산업부  하드웨어 첨단전략산업  총력대응 에 최수연 네이버 대표 포함   왜
# 34      경기동부 우수 소상공인 기획전  장인의 앞뜰리에  20일간 네이버와 롯데온에
# 35  엔씨디지텍  네이버 스토어  갤럭시북 HOT SUMMER  특가 프로모션 행사 진행
# 36              잇따라 서버 불안정 일으킨 네이버  트래픽 집중 대비책 세워야
# 37                     당정  네이버 다음 독과점 심각 연내 정상화할 것
# 38                   밀린 코스피  LG에너지솔루션 네이버 등 엇갈린 주가
# 39               신세계 유니버스클럽 흥행할까 쿠팡 네이버 멤버십과 비교해보니
# 40          태평양도서 5개국  네이버 1784 방문  IT 기술력이 국가 경쟁력
# 41               네이버 인물정보 항목 다양화 본인 참여 서비스 모바일로 확대
# 42                        통계청 네이버  초거대 AI 협업 방안 모색
# 43                 네이버 토스 대환대출 플랫폼에 국민 신한은행 빠진 까닭은
# 44                                    SKT KT 네이버 외
# 45             회원관리 손쉽게  카페24  네이버 로그인 플러스 위자드  선봬
# 46                   네이버  임직원과 로컬 SME가 직접 만나 소통 강화
# 47              한상혁 찍어내고 네이버 다음 손보기   관제 포털  시대 오나
# 48                  네이버  뷰티 해외직구 윈도  종료 패션타운에 새 둥지
# 49                      앳홈  미닉스 미니 건조기 네이버 쇼핑에서 론칭
#
#                                                Tokens
# 0                   [네이버, 금지, 혐오, 표현, 기준, 개정, 정책, 적용]
# 1                [네이버, 거대, 상공인, 라이브, 커머스, 대본, 작성, 이유]
# 2                           [네이버, 악성, 댓글, 때, 악플, 꼬리표]
# 3                             [네이버, 중소, 상공인, 브랜드, 구축]
# 4                 [네이버, 카카오, 인물, 정보, 장례, 지도사, 직업, 추가]
# 5                         [현대차, 네이버, 하이퍼클로바, 시장, 연착륙]
# 6                 [재난, 상황, 주연, 네이버, 공공, 인프라, 플랫폼, 책임]
# 7                          [웹툰, 논란, 네이버, 카카오, 인간, 작품]
# 8                 [네이버, 투자, 패션, 플랫폼, 브랜디, 자금, 수혈, 필요]
# 9                                   [네이버, 마비, 복구, 재난]
# 10                           [트위터, 네이버, 사용, 실, 검, 부활]
# 11             [김현철, 국정, 개입, 폭로, 의사, 네이버, 고소, 자료, 파기]
# 12                 [소년, 판타지, 네이버, 나우, 아베, 방송, 동시, 중계]
# 13                         [주치의, 네이버, 고소, 자료, 무단, 삭제]
# 14                  [발사체, 경보, 뒤, 네이버, 먹통, 시민, 혼란, 가중]
# 15                      [네이버, 계열사, 곳, 임금, 인상, 잠정, 합의]
# 16          [포털, 위, 네이버, 뉴스, 개편, 언론사, 클릭, 장사, 격화, 우려]
# 17                         [네이버, 페이, 대출, 오픈, 금리, 포인트]
# 18                        [네이버, 검색, 순위, 조작, 은, 돈, 검찰]
# 19               [네이버, 판, 로켓, 배송, 네이버, 도착, 보장, 맘, 카페]
# 20                            [발사체, 네이버, 모바일, 접속, 장애]
# 21               [원총, 네이버, 겨냥, 뉴스, 장사, 뉴스, 공정, 얘기, 때]
# 22         [트리니티, 소프트, 코드, 레이, 엑스, 네이버, 마켓, 플레이스, 등록]
# 23                                      [네이버, 로봇, 미래]
# 24                              [발사체, 경보, 뒤, 네이버, 먹통]
# 25                          [네이버, 생성, 도입, 검색, 광고, 수요]
# 26                    [서비스, 개편, 네이버, 카카오, 먹거리, 발굴, 속]
# 27                     [오, 퀴즈, 웨스트, 네이버, 쇼핑, 라이브, 정답]
# 28                 [미래에셋증권, 네이버 클라우드, 빅데이터, 페스티벌, 개최]
# 29                          [재난, 경보, 먹통, 네이버, 서버, 확충]
# 30                [단기, 차입금, 증가, 네이버 클라우드, 하이퍼클로바, 기회]
# 31                [서울, 디지털, 재단, 네이버 클라우드, 업무, 협약, 체결]
# 32                          [글로벌, 학회, 논문, 수, 삼성, 네이버]
# 33  [산업부, 하드웨어, 첨단, 전략, 산업, 총력, 대응, 최, 수연, 네이버, 대표...
# 34         [경기, 동부, 우수, 상공인, 기획전, 장인, 앞뜰, 네이버, 롯데, 온]
# 35        [엔씨디지텍, 네이버, 스토어, 갤럭시, 북, 특가, 프로모션, 행사, 진행]
# 36                        [서버, 안정, 네이버, 트래픽, 집중, 대비책]
# 37                         [당정, 네이버, 다음, 독과점, 연내, 정상]
# 38                           [코스피, 에너지, 솔루션, 네이버, 주가]
# 39              [신세계, 유니버스, 클럽, 흥행, 쿠팡, 네이버, 멤버십, 비교]
# 40                    [태평양, 도서, 네이버, 방문, 기술, 국가, 경쟁력]
# 41        [네이버, 인물, 정보, 항목, 다양, 본인, 참여, 서비스, 모바일, 확대]
# 42                         [통계청, 네이버, 거대, 협업, 방안, 모색]
# 43               [네이버, 토스, 대화, 대출, 플랫폼, 국민, 신한은행, 까닭]
# 44                                              [네이버]
# 45                   [회원, 관리, 카페, 네이버, 로그인, 플러스, 위자드]
# 46                             [네이버, 임직원, 로컬, 소통, 강화]
# 47                    [한상혁, 네이버, 다음, 손보기, 관제, 포털, 시대]
# 48                [네이버, 뷰티, 해외직구, 윈도, 종료, 패션, 타운, 둥지]
# 49                     [홈, 미닉스, 미니, 건조기, 네이버, 쇼핑, 론칭]

# %% [markdown]
# # <span style="color:pink"> --- 중간 저장 -------------

# %%
# CSV 파일로 저장
news.to_csv('naver_01.Preprocessing_01.csv', index=False)

# %% [markdown]
# # 5. 각 행의 리스트를 문자열로 결합하고 컴마 제거

# %%
import pandas as pd 
news_copy = pd.read_csv('naver_01.Preprocessing_01.csv')

# %%
# Tokens 열을 문자열로 변환
news_copy['Tokens'] = news_copy['Tokens'].astype(str)

# %%
# ### 5. Tokens 열에서 리스트 기호와 쉼표 제거
# news['Tokens'] = news['Tokens'].str.replace("[\[\]']", "", regex=True)
# news['Tokens'] = news['Tokens'].str.replace(",", "", regex=False)
# news

# %%
### 5. Tokens 열에서 리스트 기호와 쉼표 제거
news_copy['Tokens'] = news_copy['Tokens'].str.replace("[\[\]']", "", regex=True)
news_copy['Tokens'] = news_copy['Tokens'].str.replace(",", "", regex=False)
news_copy
# Out:
#             Date                                              Title  \
# 0     2023-06-01                    네이버, 금지·혐오 표현 기준 개정…12일부터 정책 적용
# 1     2023-06-01               네이버, 초거대 AI로 소상공인 라이브커머스 대본 작성 돕는 이유
# 2     2023-06-01                            네이버 악성 댓글땐 ‘악플러 꼬리표’ 단다
# 3     2023-06-01                          네이버가 4달간 중소상공인 브랜드 구축 돕는다
# 4     2023-06-01                   네이버·카카오 인물정보에 '장례지도사' 등 5개 직업 추가
# ...          ...                                                ...
# 9316  2024-05-27                티몬, 브랜드 단위 협업으로 직구 강화…"큐텐 시너지로 차별화"
# 9317  2024-05-27      카카오·라인야후, 어떻게 해커에 뚫렸나… “오픈채팅방 ID 구조 단순”vs“...
# 9318  2024-05-27      네이버웹툰 ‘꿈에서 자유로’ 오는 6월 두 번째 오디오 웹툰 텀블럭 펀딩 실...
# 9319  2024-05-27                 “삼성 출신 들어가니 좀 달라졌네”…요즘 국회는 ‘AI 열공’
# 9320  2024-05-27  [창간 9주년 韓에 AI(혼)를 심다] 최수연 네이버 대표 "올해 서비스 전반에 생...
#
#                                        ppc_Title  \
# 0                네이버  금지 혐오 표현 기준 개정 12일부터 정책 적용
# 1           네이버  초거대 AI로 소상공인 라이브커머스 대본 작성 돕는 이유
# 2                        네이버 악성 댓글땐  악플러 꼬리표  단다
# 3                      네이버가 4달간 중소상공인 브랜드 구축 돕는다
# 4               네이버 카카오 인물정보에  장례지도사  등 5개 직업 추가
# ...                                          ...
# 9316          티몬  브랜드 단위 협업으로 직구 강화  큐텐 시너지로 차별화
# 9317   카카오 라인야후  어떻게 해커에 뚫렸나   오픈채팅방 ID 구조 단순 VS
# 9318  네이버웹툰  꿈에서 자유로  오는 6월 두 번째 오디오 웹툰 텀블럭 펀딩 실
# 9319            삼성 출신 들어가니 좀 달라졌네  요즘 국회는  AI 열공
# 9320                    최수연 네이버 대표  올해 서비스 전반에 생
#
#                              Tokens
# 0          네이버 금지 혐오 표현 기준 개정 정책 적용
# 1       네이버 거대 상공인 라이브 커머스 대본 작성 이유
# 2                네이버 악성 댓글 때 악플 꼬리표
# 3                 네이버 중소 상공인 브랜드 구축
# 4        네이버 카카오 인물 정보 장례 지도사 직업 추가
# ...                             ...
# 9316  티몬 브랜드 단위 협업 직구 강화 큐 텐 시너지 차별
# 9317      카카오 라인 야후 해커 오픈 채팅방 구조 단순
# 9318   네이버 웹툰 꿈 자유 오디오 웹툰 텀 블럭 펀딩 실
# 9319                    삼성 출신 요즘 국회
# 9320        최 수연 네이버 대표 올해 서비스 전반 생
#
# [9321 rows x 4 columns]

# %%
# CSV 파일로 저장
news_copy.to_csv('naver_01.Preprocessing_02.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# # 6. 결측치 확인 및 제거

# %%
import pandas as pd 
news_check = pd.read_csv('naver_01.Preprocessing_02.csv')
news_check.head()
# Out:
#          Date                                 Title  \
# 0  2023-06-01       네이버, 금지·혐오 표현 기준 개정…12일부터 정책 적용
# 1  2023-06-01  네이버, 초거대 AI로 소상공인 라이브커머스 대본 작성 돕는 이유
# 2  2023-06-01               네이버 악성 댓글땐 ‘악플러 꼬리표’ 단다
# 3  2023-06-01             네이버가 4달간 중소상공인 브랜드 구축 돕는다
# 4  2023-06-01      네이버·카카오 인물정보에 '장례지도사' 등 5개 직업 추가
#
#                               ppc_Title                       Tokens
# 0       네이버  금지 혐오 표현 기준 개정 12일부터 정책 적용     네이버 금지 혐오 표현 기준 개정 정책 적용
# 1  네이버  초거대 AI로 소상공인 라이브커머스 대본 작성 돕는 이유  네이버 거대 상공인 라이브 커머스 대본 작성 이유
# 2               네이버 악성 댓글땐  악플러 꼬리표  단다           네이버 악성 댓글 때 악플 꼬리표
# 3             네이버가 4달간 중소상공인 브랜드 구축 돕는다            네이버 중소 상공인 브랜드 구축
# 4      네이버 카카오 인물정보에  장례지도사  등 5개 직업 추가   네이버 카카오 인물 정보 장례 지도사 직업 추가

# %%
news_check[news_check['Tokens'].isna()]
# Out:
#             Date                     Title  ppc_Title Tokens
# 5619  2024-01-03         1559호를 읽고[독자의 소리]  1559호를 읽고    NaN
# 8928  2024-05-10  [연합뉴스 이 시각 헤드라인] - 14:30      14 30    NaN

# %%
### 6. 결측치 제거
news = news.dropna(subset=['Tokens'])
news[news['Tokens'].isna()]
# Out:
# Empty DataFrame
# Columns: [Date, Title, ppc_Title, Tokens]
# Index: []

# %%
### 6. 결측치 제거
news_check = news_check.dropna(subset=['Tokens'])
news_check[news_check['Tokens'].isna()]
# Out:
# Empty DataFrame
# Columns: [Date, Title, ppc_Title, Tokens]
# Index: []

# %%
# CSV 파일로 저장
news_check.to_csv('naver_01.Preprocessing_FIN.csv', index=False)

# %% [markdown]
# ---

# %%
# 잘 저장 됐는지 확인
import pandas as pd 
news_check2 = pd.read_csv('naver_01.Preprocessing_FIN.csv')

# %%
news_check2[news_check2['Tokens'].isna()]
# Out:
# Empty DataFrame
# Columns: [Date, Title, ppc_Title, Tokens]
# Index: []

# %%
news_check2.head(60)
# Out:
#           Date                                           Title  \
# 0   2023-06-01                 네이버, 금지·혐오 표현 기준 개정…12일부터 정책 적용
# 1   2023-06-01            네이버, 초거대 AI로 소상공인 라이브커머스 대본 작성 돕는 이유
# 2   2023-06-01                         네이버 악성 댓글땐 ‘악플러 꼬리표’ 단다
# 3   2023-06-01                       네이버가 4달간 중소상공인 브랜드 구축 돕는다
# 4   2023-06-01                네이버·카카오 인물정보에 '장례지도사' 등 5개 직업 추가
# 5   2023-06-01                   현대차證 “네이버, 하이퍼클로바X 시장 연착륙할 것”
# 6   2023-06-01          재난상황 ‘주연’된 네이버...공공인프라 된 플랫폼, 책임 어디까지?
# 7   2023-06-01                  AI 웹툰 논란에 네이버·카카오 "인간 작품만 받는다"
# 8   2023-06-01             네이버가 300억 투자한 패션 플랫폼 ‘브랜디’ 자금 수혈 필요
# 9   2023-06-01                네이버 마비, 5분 만에 복구됐지만… 실제 재난에선 어쩌나
# 10  2023-06-01            “트위터 보단 네이버 사용자가 훨씬 많은데…‘실검’ 부활시켰으면”
# 11  2023-06-01              ‘김현철 국정개입 폭로’ 의사, 네이버 고소…“내 자료 파기”
# 12  2023-06-01  ‘소년판타지’, MBC-네이버 나우-아베마(ABEMA), 127분 생방송 동시 중계
# 13  2023-06-01                    前 YS 주치의, 네이버 고소…"내 자료 무단삭제"
# 14  2023-06-01                北 발사체 경보 뒤 네이버 5분간 먹통… 시민들 혼란 가중
# 15  2023-06-01                    네이버 계열사 7곳, 임금인상 4.8~6% 잠정합의
# 16  2023-06-01           與 포털위, 네이버 뉴스 개편에 "언론사 클릭장사 격화 우려 나와"
# 17  2023-06-01    네이버페이 대출 갈아타기 오픈… 낮은 금리로 갈아타고 잘 갚으면 포인트 지...
# 18  2023-06-01             '네이버 검색 순위 조작'은 돈이 된다, 하지만 검찰에 들켰죠?
# 19  2023-06-01            "네이버판 로켓배송인거에요?" 네이버 도착보장에 맘카페도 '꿈틀'
# 20  2023-06-01                           北 발사체에 네이버도 모바일 접속 장애
# 21  2023-06-01               언총, 네이버 겨냥 "뉴스장사 아닌 뉴스 공정성 얘기할 때"
# 22  2023-06-01          트리니티소프트 '코드레이 엑스지 V6.0', 네이버 마켓플레이스 등록
# 23  2023-06-01                [오늘의 증시 리포트] “네이버, AI와 로봇에 건 미래”
# 24  2023-06-01                           北 발사체 경보 뒤 네이버 5분간 먹통
# 25  2023-06-01                네이버 "생성형 AI 도입돼도 검색 광고 수요 여전할 것"
# 26  2023-06-01                  서비스 개편 나선 네이버ㆍ카카오, 새 먹거리 발굴 속도
# 27  2023-06-01                   오퀴즈 '에스트라 네이버 쇼핑 라이브' 8시 정답은?
# 28  2023-06-01             미래에셋증권, 네이버클라우드와 손잡고 ‘빅데이터 페스티벌’ 개최
# 29  2023-06-01                        재난 경보에 먹통된 네이버…"서버 확충해야"
# 30  2023-06-01            '단기차입금' 증가한 네이버클라우드, 하이퍼클로바X로 기회 찾을까
# 31  2023-06-01                       서울디지털재단–네이버클라우드, 업무 협약 체결
# 32  2023-06-01             글로벌 3대 AI학회 논문수, 삼성 17위-네이버 18위 머물러
# 33  2023-06-01     산업부, 하드웨어 첨단전략산업 '총력대응'에 최수연 네이버 대표 포함...왜?
# 34  2023-06-01   경기동부 우수 소상공인 기획전 '장인의 앞뜰리에' 20일간 네이버와 롯데온에...
# 35  2023-06-01  엔씨디지텍, 네이버 스토어 '갤럭시북 HOT SUMMER' 특가 프로모션 행사 진행
# 36  2023-06-01             잇따라 서버 불안정 일으킨 네이버…“트래픽 집중 대비책 세워야”
# 37  2023-06-01       [포털 정상화 속도전] 당정 "네이버·다음 독과점 심각…연내 정상화할 것"
# 38  2023-06-01          [종합주가지수] 밀린 코스피, LG에너지솔루션·네이버 등 엇갈린 주가
# 39  2023-06-01               신세계 유니버스클럽 흥행할까…쿠팡·네이버 멤버십과 비교해보니
# 40  2023-06-02         태평양도서 5개국, 네이버 1784 방문…"IT 기술력이 국가 경쟁력"
# 41  2023-06-02               네이버 인물정보 항목 다양화…본인 참여 서비스 모바일로 확대
# 42  2023-06-02                        통계청-네이버, 초거대 AI 협업 방안 모색
# 43  2023-06-02          네이버·토스 대환대출 플랫폼에 국민·신한은행 빠진 까닭은[경제블로그]
# 44  2023-06-02                               [잇속] SKT·KT·네이버 외
# 45  2023-06-02            "회원관리 손쉽게"…카페24 '네이버 로그인 플러스 위자드' 선봬
# 46  2023-06-02                   네이버, 임직원과 로컬 SME가 직접 만나 소통 강화
# 47  2023-06-02              한상혁 찍어내고 네이버·다음 손보기? '관제 포털' 시대 오나
# 48  2023-06-02                  네이버 '뷰티·해외직구 윈도' 종료…패션타운에 새 둥지
# 49  2023-06-02                      앳홈, 미닉스 미니 건조기 네이버 쇼핑에서 론칭
# 50  2023-06-02         임영웅 '마리히' 2회도 기대감 '쑥쑥'..선공개 3차 네이버TV 1위
# 51  2023-06-02          최민호 시장, 네이버 데이터센터 현장 방문···“안전사고 예방” 당부
# 52  2023-06-02    ‘장례지도사’ ‘웨딩플래너’ 등 5개 직업군, 네이버·카카오 인물정보에 등...
# 53  2023-06-02        네이버, 핀테크 관련 상장기업 브랜드평판 1위···카카오페이·KT 뒤쫓아
# 54  2023-06-02                양산부산대병원, 네이버 클라우드와 업무협약…의료 혁신 앞장
# 55  2023-06-02                        네이버데이터센터 공사 현장 둘러보는 세종시장
# 56  2023-06-02                       네이버, 금지 혐오표현 구체화…12일부터 적용
# 57  2023-06-02              네이버·카카오, '성소수자(LGBTQ) 혐오' 표현 제재 나서
# 58  2023-06-02          네이버 크림, 구매거부 기능 도입…C2C 플랫폼 소비자 보호 ‘시동’
# 59  2023-06-02                       X쌍도·딸X…네이버에서 혐오표현 쓰면 ‘삭제’
#
#                                          ppc_Title  \
# 0                  네이버  금지 혐오 표현 기준 개정 12일부터 정책 적용
# 1             네이버  초거대 AI로 소상공인 라이브커머스 대본 작성 돕는 이유
# 2                          네이버 악성 댓글땐  악플러 꼬리표  단다
# 3                        네이버가 4달간 중소상공인 브랜드 구축 돕는다
# 4                 네이버 카카오 인물정보에  장례지도사  등 5개 직업 추가
# 5                     현대차證  네이버  하이퍼클로바X 시장 연착륙할 것
# 6            재난상황  주연 된 네이버   공공인프라 된 플랫폼  책임 어디까지
# 7                    AI 웹툰 논란에 네이버 카카오  인간 작품만 받는다
# 8              네이버가 300억 투자한 패션 플랫폼  브랜디  자금 수혈 필요
# 9                 네이버 마비  5분 만에 복구됐지만  실제 재난에선 어쩌나
# 10              트위터 보단 네이버 사용자가 훨씬 많은데  실검  부활시켰으면
# 11                김현철 국정개입 폭로  의사  네이버 고소  내 자료 파기
# 12   소년판타지   MBC 네이버 나우 아베마 ABEMA   127분 생방송 동시 중계
# 13                     前 YS 주치의  네이버 고소  내 자료 무단삭제
# 14                北 발사체 경보 뒤 네이버 5분간 먹통  시민들 혼란 가중
# 15                    네이버 계열사 7곳  임금인상 4 8 6  잠정합의
# 16            與 포털위  네이버 뉴스 개편에  언론사 클릭장사 격화 우려 나와
# 17       네이버페이 대출 갈아타기 오픈  낮은 금리로 갈아타고 잘 갚으면 포인트 지
# 18               네이버 검색 순위 조작 은 돈이 된다  하지만 검찰에 들켰죠
# 19              네이버판 로켓배송인거에요   네이버 도착보장에 맘카페도  꿈틀
# 20                           北 발사체에 네이버도 모바일 접속 장애
# 21                언총  네이버 겨냥  뉴스장사 아닌 뉴스 공정성 얘기할 때
# 22          트리니티소프트  코드레이 엑스지 V6 0   네이버 마켓플레이스 등록
# 23                               네이버  AI와 로봇에 건 미래
# 24                           北 발사체 경보 뒤 네이버 5분간 먹통
# 25                 네이버  생성형 AI 도입돼도 검색 광고 수요 여전할 것
# 26                  서비스 개편 나선 네이버ㆍ카카오  새 먹거리 발굴 속도
# 27                    오퀴즈  에스트라 네이버 쇼핑 라이브  8시 정답은
# 28             미래에셋증권  네이버클라우드와 손잡고  빅데이터 페스티벌  개최
# 29                         재난 경보에 먹통된 네이버  서버 확충해야
# 30             단기차입금  증가한 네이버클라우드  하이퍼클로바X로 기회 찾을까
# 31                       서울디지털재단 네이버클라우드  업무 협약 체결
# 32             글로벌 3대 AI학회 논문수  삼성 17위 네이버 18위 머물러
# 33      산업부  하드웨어 첨단전략산업  총력대응 에 최수연 네이버 대표 포함   왜
# 34      경기동부 우수 소상공인 기획전  장인의 앞뜰리에  20일간 네이버와 롯데온에
# 35  엔씨디지텍  네이버 스토어  갤럭시북 HOT SUMMER  특가 프로모션 행사 진행
# 36              잇따라 서버 불안정 일으킨 네이버  트래픽 집중 대비책 세워야
# 37                     당정  네이버 다음 독과점 심각 연내 정상화할 것
# 38                   밀린 코스피  LG에너지솔루션 네이버 등 엇갈린 주가
# 39               신세계 유니버스클럽 흥행할까 쿠팡 네이버 멤버십과 비교해보니
# 40          태평양도서 5개국  네이버 1784 방문  IT 기술력이 국가 경쟁력
# 41               네이버 인물정보 항목 다양화 본인 참여 서비스 모바일로 확대
# 42                        통계청 네이버  초거대 AI 협업 방안 모색
# 43                 네이버 토스 대환대출 플랫폼에 국민 신한은행 빠진 까닭은
# 44                                    SKT KT 네이버 외
# 45             회원관리 손쉽게  카페24  네이버 로그인 플러스 위자드  선봬
# 46                   네이버  임직원과 로컬 SME가 직접 만나 소통 강화
# 47              한상혁 찍어내고 네이버 다음 손보기   관제 포털  시대 오나
# 48                  네이버  뷰티 해외직구 윈도  종료 패션타운에 새 둥지
# 49                      앳홈  미닉스 미니 건조기 네이버 쇼핑에서 론칭
# 50         임영웅  마리히  2회도 기대감  쑥쑥   선공개 3차 네이버TV 1위
# 51          최민호 시장  네이버 데이터센터 현장 방문    안전사고 예방  당부
# 52        장례지도사   웨딩플래너  등 5개 직업군  네이버 카카오 인물정보에 등
# 53        네이버  핀테크 관련 상장기업 브랜드평판 1위   카카오페이 KT 뒤쫓아
# 54                양산부산대병원  네이버 클라우드와 업무협약 의료 혁신 앞장
# 55                        네이버데이터센터 공사 현장 둘러보는 세종시장
# 56                       네이버  금지 혐오표현 구체화 12일부터 적용
# 57              네이버 카카오   성소수자 LGBTQ  혐오  표현 제재 나서
# 58           네이버 크림  구매거부 기능 도입 C2C 플랫폼 소비자 보호  시동
# 59                        X쌍도 딸X 네이버에서 혐오표현 쓰면  삭제
#
#                                     Tokens
# 0                 네이버 금지 혐오 표현 기준 개정 정책 적용
# 1              네이버 거대 상공인 라이브 커머스 대본 작성 이유
# 2                       네이버 악성 댓글 때 악플 꼬리표
# 3                        네이버 중소 상공인 브랜드 구축
# 4               네이버 카카오 인물 정보 장례 지도사 직업 추가
# 5                    현대차 네이버 하이퍼클로바 시장 연착륙
# 6               재난 상황 주연 네이버 공공 인프라 플랫폼 책임
# 7                      웹툰 논란 네이버 카카오 인간 작품
# 8               네이버 투자 패션 플랫폼 브랜디 자금 수혈 필요
# 9                             네이버 마비 복구 재난
# 10                       트위터 네이버 사용 실 검 부활
# 11            김현철 국정 개입 폭로 의사 네이버 고소 자료 파기
# 12               소년 판타지 네이버 나우 아베 방송 동시 중계
# 13                     주치의 네이버 고소 자료 무단 삭제
# 14                발사체 경보 뒤 네이버 먹통 시민 혼란 가중
# 15                   네이버 계열사 곳 임금 인상 잠정 합의
# 16          포털 위 네이버 뉴스 개편 언론사 클릭 장사 격화 우려
# 17                     네이버 페이 대출 오픈 금리 포인트
# 18                     네이버 검색 순위 조작 은 돈 검찰
# 19              네이버 판 로켓 배송 네이버 도착 보장 맘 카페
# 20                       발사체 네이버 모바일 접속 장애
# 21              원총 네이버 겨냥 뉴스 장사 뉴스 공정 얘기 때
# 22        트리니티 소프트 코드 레이 엑스 네이버 마켓 플레이스 등록
# 23                               네이버 로봇 미래
# 24                         발사체 경보 뒤 네이버 먹통
# 25                      네이버 생성 도입 검색 광고 수요
# 26                 서비스 개편 네이버 카카오 먹거리 발굴 속
# 27                  오 퀴즈 웨스트 네이버 쇼핑 라이브 정답
# 28            미래에셋증권 네이버 클라우드 빅데이터 페스티벌 개최
# 29                      재난 경보 먹통 네이버 서버 확충
# 30            단기 차입금 증가 네이버 클라우드 하이퍼클로바 기회
# 31             서울 디지털 재단 네이버 클라우드 업무 협약 체결
# 32                      글로벌 학회 논문 수 삼성 네이버
# 33  산업부 하드웨어 첨단 전략 산업 총력 대응 최 수연 네이버 대표 포함
# 34         경기 동부 우수 상공인 기획전 장인 앞뜰 네이버 롯데 온
# 35       엔씨디지텍 네이버 스토어 갤럭시 북 특가 프로모션 행사 진행
# 36                    서버 안정 네이버 트래픽 집중 대비책
# 37                     당정 네이버 다음 독과점 연내 정상
# 38                      코스피 에너지 솔루션 네이버 주가
# 39            신세계 유니버스 클럽 흥행 쿠팡 네이버 멤버십 비교
# 40                 태평양 도서 네이버 방문 기술 국가 경쟁력
# 41        네이버 인물 정보 항목 다양 본인 참여 서비스 모바일 확대
# 42                     통계청 네이버 거대 협업 방안 모색
# 43             네이버 토스 대화 대출 플랫폼 국민 신한은행 까닭
# 44                                     네이버
# 45                회원 관리 카페 네이버 로그인 플러스 위자드
# 46                        네이버 임직원 로컬 소통 강화
# 47                 한상혁 네이버 다음 손보기 관제 포털 시대
# 48              네이버 뷰티 해외직구 윈도 종료 패션 타운 둥지
# 49                  홈 미닉스 미니 건조기 네이버 쇼핑 론칭
# 50                    임영웅 마리히 기대감 선 공개 네이버
# 51      최민호 시장 네이버 데이터 센터 현장 방문 안전사고 예방 당부
# 52          장례 지도사 웨딩플래너 직업군 네이버 카카오 인물 정보
# 53           네이버 핀테크 관련 상장 기업 브랜드 평판 카카오페이
# 54        양산 부산대병원 네이버 클라우드 업무 협약 의료 혁신 앞장
# 55                  네이버 데이터 센터 공사 현장 세종 시장
# 56                      네이버 금지 혐오 표현 구체 적용
# 57                  네이버 카카오 성 소수자 혐오 표현 제재
# 58        네이버 크림 구매 거부 기능 도입 플랫폼 소비자 보호 시동
# 59                        쌍 딸 네이버 혐오 표현 삭제

# %%
def find_sentiment_words(tokens, word_dict):
    pos_words = []
    neg_words = []
    zero_words = []
    sentiment_words = []

    total_polarity = 0

    for token in tokens.split():  # 각 단어를 공백 기준으로 분리
        if token in word_dict:
            sentiment_words.append(token)
            if word_dict[token] > 0:
                pos_words.append(token)
                total_polarity += word_dict[token]
            elif word_dict[token] < 0:
                neg_words.append(token)
                total_polarity += word_dict[token]
            else:
                zero_words.append(token)
        else:
            zero_words.append(token)

    return sentiment_words, pos_words, neg_words, zero_words, total_polarity

# 예제 데이터프레임과 word_dict를 사용하여 결과를 계산
sentiment_results = news['Stop_tokens'].apply(lambda x: find_sentiment_words(x, word_dict))

# 결과 출력
sentiment_results
